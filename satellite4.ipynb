# %%
import os

for root, dirs, files in os.walk("/content/drive/MyDrive"):
    if "X_train_features.npy" in files:
        print("FOUND:", os.path.join(root, "X_train_features.npy"))

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np

DATA_PATH = "/content/drive/MyDrive/processed/processed"

X_train_raw = np.load(f"{DATA_PATH}/X_train_features.npy")
train_chan_ids = np.load(f"{DATA_PATH}/train_chan_ids.npy", allow_pickle=True)
X_test = np.load(f"{DATA_PATH}/X_features.npy")
y_test = np.load(f"{DATA_PATH}/y_labels.npy")
test_chan_ids = np.load(f"{DATA_PATH}/chan_ids.npy", allow_pickle=True)

def clean_features(X, chan_ids, y=None, name=""):
    bad_mask = np.isnan(X).any(axis=1) | np.isinf(X).any(axis=1)
    print(f"{name}: {bad_mask.sum()} bad rows out of {len(X)}")
    X_clean = X[~bad_mask]; chan_ids_clean = chan_ids[~bad_mask]
    if y is not None:
        return X_clean, chan_ids_clean, y[~bad_mask]
    return X_clean, chan_ids_clean

X_train_raw, train_chan_ids = clean_features(X_train_raw, train_chan_ids, name="train/")
X_test, test_chan_ids, y_test = clean_features(X_test, test_chan_ids, y_test, name="test/")

print("train/:", X_train_raw.shape, "| test/:", X_test.shape, "| anomalous:", y_test.sum())
# Out:
# Mounted at /content/drive
# train/: 0 bad rows out of 9599
# test/: 0 bad rows out of 25522
# train/: (9599, 504) | test/: (25522, 504) | anomalous: 3459

# %%
def check_contiguous(chan_ids, name=""):
    problems = []
    for chan in np.unique(chan_ids):
        idx = np.where(chan_ids == chan)[0]
        if idx.max() - idx.min() + 1 != len(idx):
            problems.append(chan)
    if problems:
        print(f"{name}: PROBLEM - these channels are NOT stored as contiguous chronological blocks: {problems}")
    else:
        print(f"{name}: OK - every channel's rows are one unbroken block (order preserved)")

check_contiguous(train_chan_ids, "train_chan_ids")
check_contiguous(test_chan_ids, "test_chan_ids")
# Out:
# train_chan_ids: PROBLEM - these channels are NOT stored as contiguous chronological blocks: [np.str_('P-2')]
# test_chan_ids: PROBLEM - these channels are NOT stored as contiguous chronological blocks: [np.str_('P-2')]

# %%
import torch

# %%
import random
import torch
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

# %%
import torch, torch.nn as nn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, f1_score

SEQ_LEN = 8

class LSTMAutoencoder(nn.Module):
    def __init__(self, d, hidden=32, latent=8):
        super().__init__()
        self.encoder = nn.LSTM(d, hidden, batch_first=True)
        self.to_latent = nn.Linear(hidden, latent)
        self.from_latent = nn.Linear(latent, hidden)
        self.decoder = nn.LSTM(hidden, d, batch_first=True)
    def encode(self, x):
        _, (h, _) = self.encoder(x)
        return self.to_latent(h[-1])
    def forward(self, x):
        z = self.encode(x)
        h_dec = self.from_latent(z).unsqueeze(1).repeat(1, x.size(1), 1)
        out, _ = self.decoder(h_dec)
        return out, z

def make_sequences(feats, seq_len):
    n_seq = len(feats) // seq_len
    return feats[:n_seq*seq_len].reshape(n_seq, seq_len, -1)

def make_seq_labels(labels, seq_len):
    n_seq = len(labels) // seq_len
    lbl = labels[:n_seq*seq_len].reshape(n_seq, seq_len)
    return (lbl.mean(axis=1) > 0.2).astype(int)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %%
class ChebConv(nn.Module):
    def __init__(self, in_dim, out_dim, K=3):
        super().__init__()
        self.K = K
        self.weights = nn.ParameterList([nn.Parameter(torch.randn(in_dim, out_dim)*0.1) for _ in range(K)])
    def forward(self, X, L):
        Tx = [X, L @ X]
        for k in range(2, self.K):
            Tx.append(2 * (L @ Tx[-1]) - Tx[-2])
        return sum(Tx[k] @ self.weights[k] for k in range(self.K))

class DeepChebGNN(nn.Module):
    """Two ChebConv layers with a nonlinearity between - more expressive than one linear conv."""
    def __init__(self, in_dim, hidden_dim=16, K=3):
        super().__init__()
        self.conv1 = ChebConv(in_dim, hidden_dim, K)
        self.conv2 = ChebConv(hidden_dim, in_dim, K)
        self.act = nn.ReLU()
    def forward(self, X, L):
        h = self.act(self.conv1(X, L))
        return self.conv2(h, L)
def build_channel_graph(chan_list):
    """Nodes = channels, edges = channels sharing the same letter-prefix subsystem (e.g. E-1, E-2, E-3)."""
    n = len(chan_list)
    adj = np.zeros((n, n))
    for i, ci in enumerate(chan_list):
        for j, cj in enumerate(chan_list):
            if i != j and ci.split("-")[0] == cj.split("-")[0]:
                adj[i, j] = 1.0
    deg = adj.sum(axis=1)
    deg_inv_sqrt = np.diag(1.0 / np.sqrt(np.maximum(deg, 1e-8)))
    L = np.eye(n) - deg_inv_sqrt @ adj @ deg_inv_sqrt - np.eye(n)
    return torch.tensor(L, dtype=torch.float32)

# %%
from sklearn.linear_model import LogisticRegression
import random
from sklearn.metrics import accuracy_score, precision_score, recall_score


def make_seq_labels(labels, seq_len):
    n_seq = len(labels) // seq_len
    lbl = labels[:n_seq*seq_len].reshape(n_seq, seq_len)
    return (lbl.mean(axis=1) > 0.3).astype(int)

# ---- Step 1: fix the tune/final split ONCE, so every run is compared fairly ----
channel_splits = {}
for chan in np.unique(test_chan_ids):
    mask_test = test_chan_ids == chan
    yc_test = y_test[mask_test]
    n_seq = len(yc_test) // SEQ_LEN
    if n_seq == 0:
        continue
    seq_labels = make_seq_labels(yc_test, SEQ_LEN)
    n = len(seq_labels)
    perm = np.random.RandomState(123).permutation(n)   # FIXED split seed - same every run
    n_tune = max(1, int(0.4 * n))
    channel_splits[chan] = (perm[:n_tune], perm[n_tune:], seq_labels)

N_RUNS = 5
all_run_tune_probs = []
all_run_final_probs = []
run_f1_scores = []
tune_y_fixed, final_y_fixed = None, None

for run in range(N_RUNS):
    print(f"\n========== RUN {run+1}/{N_RUNS} ==========")
    seed = 100 + run
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed)

    channel_data = {}
    skipped = []

    for chan in np.unique(test_chan_ids):
        mask_train = train_chan_ids == chan
        Xc_train = X_train_raw[mask_train]
        mask_test = test_chan_ids == chan
        Xc_test = X_test[mask_test]
        yc_test = y_test[mask_test]

        if len(Xc_train) < SEQ_LEN*5 or len(Xc_test) < SEQ_LEN or chan not in channel_splits:
            skipped.append(chan)
            continue

        scaler = StandardScaler()
        scaler.fit(Xc_train)
        train_seq = make_sequences(Xc_train, SEQ_LEN)
        test_seq = make_sequences(Xc_test, SEQ_LEN)

        def scale_seq(seq):
            n, s, dd = seq.shape
            return scaler.transform(seq.reshape(-1, dd)).astype("float32").reshape(n, s, dd)
        train_seq_s, test_seq_s = scale_seq(train_seq), scale_seq(test_seq)

        n_val = max(1, int(0.2 * len(train_seq_s)))
        fit_seq, val_seq = train_seq_s[:-n_val], train_seq_s[-n_val:]
        if len(fit_seq) == 0 or len(val_seq) == 0:
            skipped.append(chan)
            continue

        fit_t = torch.tensor(fit_seq).to(device)
        val_t = torch.tensor(val_seq).to(device)
        test_t = torch.tensor(test_seq_s).to(device)

        model = LSTMAutoencoder(Xc_train.shape[1]).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        criterion = nn.MSELoss()

       # show_epochs = (chan == chan_list_preview) if 'chan_list_preview' in dir() else (list(np.unique(test_chan_ids)).index(chan) == 0)
        show_epochs = (chan == "D-1")
        for epoch in range(80):
            model.train()
            optimizer.zero_grad()
            out, _ = model(fit_t)
            loss = criterion(out, fit_t)
            loss.backward()
            optimizer.step()
            if show_epochs and (epoch+1) % 10 == 0:
                print(f"  [{chan}] Epoch {epoch+1}/80 | Loss: {loss.item():.4f}")

        model.eval()
        with torch.no_grad():
            val_out, val_z = model(val_t)
            val_err = ((val_out - val_t) ** 2).mean(dim=(1, 2)).cpu().numpy()
            test_out, test_z = model(test_t)
            test_err = ((test_out - test_t) ** 2).mean(dim=(1, 2)).cpu().numpy()

        channel_data[chan] = {
            "val_err_mean": val_err.mean(), "val_err_std": val_err.std() + 1e-8,
            "node_feature": val_z.mean(dim=0).cpu().numpy(),
            "test_err": test_err, "test_z_latent": test_z.cpu().numpy(),
        }

    print(f"Trained {len(channel_data)} channels, skipped {len(skipped)}")

    chan_list = list(channel_data.keys())
    L_t = build_channel_graph(chan_list).to(device)
    node_feat_dim = channel_data[chan_list[0]]["node_feature"].shape[0]
    node_features = torch.tensor(np.stack([channel_data[c]["node_feature"] for c in chan_list]), dtype=torch.float32).to(device)


    def build_adjacency(chan_list):
      n = len(chan_list)
      adj = np.zeros((n, n))
      for i, ci in enumerate(chan_list):
          for j, cj in enumerate(chan_list):
              if i != j and ci.split("-")[0] == cj.split("-")[0]:
                  adj[i, j] = 1.0
      return torch.tensor(adj, dtype=torch.float32)

    class GATLayer(nn.Module):
        def __init__(self, in_dim, out_dim):
            super().__init__()
            self.W = nn.Linear(in_dim, out_dim, bias=False)
            self.a = nn.Linear(2*out_dim, 1)
        def forward(self, X, adj):
            Wh = self.W(X)
            N = Wh.size(0)
            Wh1 = Wh.unsqueeze(1).expand(N, N, -1)
            Wh2 = Wh.unsqueeze(0).expand(N, N, -1)
            e = self.a(torch.cat([Wh1, Wh2], dim=-1)).squeeze(-1)
            e = torch.where(adj > 0, e, torch.full_like(e, -1e9))
            alpha = torch.softmax(e, dim=1)
            return alpha @ Wh, alpha

    class GATGNN(nn.Module):
        def __init__(self, in_dim, hidden_dim=16):
            super().__init__()
            self.layer1 = GATLayer(in_dim, hidden_dim)
            self.layer2 = GATLayer(hidden_dim, in_dim)
            self.act = nn.ReLU()
        def forward(self, X, adj):
            h, _ = self.layer1(X, adj)
            out, alpha = self.layer2(self.act(h), adj)
            return out, alpha

    adj_t = build_adjacency(chan_list).to(device)
    gnn = GATGNN(node_feat_dim, hidden_dim=16).to(device)
    opt_g = torch.optim.Adam(gnn.parameters(), lr=1e-2)
    for _ in range(200):
        gnn.train(); opt_g.zero_grad()
        refined, attn = gnn(node_features, adj_t)
        loss = nn.functional.mse_loss(refined, node_features)
        loss.backward(); opt_g.step()
    gnn.eval()
    with torch.no_grad():
        refined_features, final_attn = gnn(node_features, adj_t)
        refined_features = refined_features.cpu().numpy()
    # gnn = DeepChebGNN(node_feat_dim, hidden_dim=16, K=3).to(device)
    # opt_g = torch.optim.Adam(gnn.parameters(), lr=1e-2)
    # for epoch in range(200):
    #   gnn.train()
    #   opt_g.zero_grad()
    #   refined = gnn(node_features, L_t)
    #   loss = nn.functional.mse_loss(refined, node_features)
    #   loss.backward()
    #   opt_g.step()
    #   if (epoch + 1) % 10 == 0:
    #     print(f"  [GNN] Epoch {epoch+1}/200 | Loss: {loss.item():.4f}")


    # gnn.eval()
    # with torch.no_grad():
    #     refined_features = gnn(node_features, L_t).cpu().numpy()

    run_tune_X, run_tune_y, run_final_X, run_final_y = [], [], [], []
    for i, chan in enumerate(chan_list):
        cd = channel_data[chan]
        lstm_z = np.clip((cd["test_err"] - cd["val_err_mean"]) / cd["val_err_std"], -10, 10)
        graph_dist = np.linalg.norm(cd["test_z_latent"] - refined_features[i], axis=1)
        graph_z = np.clip((graph_dist - graph_dist.mean())/(graph_dist.std()+1e-8), -10, 10)

        tune_idx, final_idx, seq_labels = channel_splits[chan]
        # guard: sequence count must match what this run actually produced
        if len(lstm_z) != len(seq_labels):
            continue
        run_tune_X.append(np.column_stack([lstm_z[tune_idx], graph_z[tune_idx]]))
        run_tune_y.append(seq_labels[tune_idx])
        run_final_X.append(np.column_stack([lstm_z[final_idx], graph_z[final_idx]]))
        run_final_y.append(seq_labels[final_idx])

    X_tune = np.concatenate(run_tune_X); y_tune_r = np.concatenate(run_tune_y)
    X_final = np.concatenate(run_final_X); y_final_r = np.concatenate(run_final_y)

    combiner = LogisticRegression(class_weight="balanced")
    combiner.fit(X_tune, y_tune_r)
    all_run_tune_probs.append(combiner.predict_proba(X_tune)[:,1])
    all_run_final_probs.append(combiner.predict_proba(X_final)[:,1])
    tune_y_fixed, final_y_fixed = y_tune_r, y_final_r

    run_f1 = f1_score(final_y_fixed, (all_run_final_probs[-1] > np.median(all_run_final_probs[-1])).astype(int), zero_division=0)
    print(f"Run {run+1} single-run F1 (rough): {run_f1:.3f}")
    run_f1_scores.append(run_f1)

# ---- average across runs, threshold once on the average ----
avg_tune_probs = np.mean(all_run_tune_probs, axis=0)
avg_final_probs = np.mean(all_run_final_probs, axis=0)

candidates = np.percentile(avg_tune_probs, np.arange(50,100,1))
best_thr, best_f1_tune = None, -1
for thr in candidates:
    f1 = f1_score(tune_y_fixed, (avg_tune_probs>thr).astype(int), zero_division=0)
    if f1 > best_f1_tune:
        best_f1_tune, best_thr = f1, thr

final_preds = (avg_final_probs > best_thr).astype(int)
print(f"\n========== ENSEMBLE OF {N_RUNS} RUNS ==========")
print(classification_report(final_y_fixed, final_preds, zero_division=0))
print("Ensemble Accuracy : ", accuracy_score(final_y_fixed, final_preds))
print(f"\n========== ENSEMBLE OF {N_RUNS} RUNS (threshold=0.3) ==========")
# Out:
# ========== RUN 1/5 ==========
#   [D-1] Epoch 10/80 | Loss: 0.6490
#   [D-1] Epoch 20/80 | Loss: 0.5471
#   [D-1] Epoch 30/80 | Loss: 0.5076
#   [D-1] Epoch 40/80 | Loss: 0.4563
#   [D-1] Epoch 50/80 | Loss: 0.4224
#   [D-1] Epoch 60/80 | Loss: 0.3950
#   [D-1] Epoch 70/80 | Loss: 0.3793
#   [D-1] Epoch 80/80 | Loss: 0.3631
# Trained 73 channels, skipped 8
# Run 1 single-run F1 (rough): 0.369
#
# ========== RUN 2/5 ==========
#   [D-1] Epoch 10/80 | Loss: 0.6520
#   [D-1] Epoch 20/80 | Loss: 0.5509
#   [D-1] Epoch 30/80 | Loss: 0.4782
#   [D-1] Epoch 40/80 | Loss: 0.4448
#   [D-1] Epoch 50/80 | Loss: 0.4079
#   [D-1] Epoch 60/80 | Loss: 0.3851
#   [D-1] Epoch 70/80 | Loss: 0.3632
#   [D-1] Epoch 80/80 | Loss: 0.3462
# Trained 73 channels, skipped 8
# Run 2 single-run F1 (rough): 0.362
#
# ========== RUN 3/5 ==========
#   [D-1] Epoch 10/80 | Loss: 0.6318
#   [D-1] Epoch 20/80 | Loss: 0.5517
#   [D-1] Epoch 30/80 | Loss: 0.4910
#   [D-1] Epoch 40/80 | Loss: 0.4585
#   [D-1] Epoch 50/80 | Loss: 0.4226
#   [D-1] Epoch 60/80 | Loss: 0.4167
#   [D-1] Epoch 70/80 | Loss: 0.3845
#   [D-1] Epoch 80/80 | Loss: 0.3724
# Trained 73 channels, skipped 8
# Run 3 single-run F1 (rough): 0.355
#
# ========== RUN 4/5 ==========
#   [D-1] Epoch 10/80 | Loss: 0.6466
#   [D-1] Epoch 20/80 | Loss: 0.5659
#   [D-1] Epoch 30/80 | Loss: 0.5488
#   [D-1] Epoch 40/80 | Loss: 0.5069
#   [D-1] Epoch 50/80 | Loss: 0.4665
#   [D-1] Epoch 60/80 | Loss: 0.4243
#   [D-1] Epoch 70/80 | Loss: 0.3939
#   [D-1] Epoch 80/80 | Loss: 0.3699
# Trained 73 channels, skipped 8
# Run 4 single-run F1 (rough): 0.372
#
# ========== RUN 5/5 ==========
#   [D-1] Epoch 10/80 | Loss: 0.6465
#   [D-1] Epoch 20/80 | Loss: 0.5525
#   [D-1] Epoch 30/80 | Loss: 0.4889
#   [D-1] Epoch 40/80 | Loss: 0.4662
#   [D-1] Epoch 50/80 | Loss: 0.4239
#   [D-1] Epoch 60/80 | Loss: 0.3883
#   [D-1] Epoch 70/80 | Loss: 0.3717
#   [D-1] Epoch 80/80 | Loss: 0.3638
# Trained 73 channels, skipped 8
# Run 5 single-run F1 (rough): 0.366
#
# ========== ENSEMBLE OF 5 RUNS ==========
#               precision    recall  f1-score   support
#
#            0       0.93      0.73      0.82      1524
#            1       0.30      0.70      0.42       258
#
#     accuracy                           0.72      1782
#    macro avg       0.62      0.71      0.62      1782
# weighted avg       0.84      0.72      0.76      1782
#
# Ensemble Accuracy :  0.7210998877665544
#
# ========== ENSEMBLE OF 5 RUNS (threshold=0.3) ==========

# %%
# ---- mean/std across runs ----
print(f"\nMean F1 across {N_RUNS} runs: {np.mean(run_f1_scores):.3f} ± {np.std(run_f1_scores):.3f}")
print(f"Min: {min(run_f1_scores):.3f}  Max: {max(run_f1_scores):.3f}")

# ---- skipped channels ----
print("\nSkipped channels:")
for chan in skipped:
    n_tr = (train_chan_ids == chan).sum()
    n_te = (test_chan_ids == chan).sum()
    reason = "too few train windows" if n_tr < SEQ_LEN*5 else "too few test/other"
    print(f"  {chan}: train={n_tr}, test={n_te} -> {reason}")

# ---- ablation: LSTM only vs GNN only vs combined (uses last run's channel_data) ----
def eval_score(score, labels, tune_idx, final_idx):
    cands = np.percentile(score[tune_idx], np.arange(50,100,1))
    bthr, bf1 = None, -1
    for thr in cands:
        f1 = f1_score(labels[tune_idx], (score[tune_idx]>thr).astype(int), zero_division=0)
        if f1 > bf1: bf1, bthr = f1, thr
    return f1_score(labels[final_idx], (score[final_idx]>bthr).astype(int), zero_division=0)

lstm_only_scores, gnn_only_scores, combined_scores, labels_all, tune_all, final_all = [],[],[],[],[],[]
offset = 0
for i, chan in enumerate(chan_list):
    cd = channel_data[chan]
    tune_idx, final_idx, seq_labels = channel_splits[chan]
    lstm_z = np.clip((cd["test_err"]-cd["val_err_mean"])/cd["val_err_std"], -10,10)
    graph_dist = np.linalg.norm(cd["test_z_latent"] - refined_features[i], axis=1)
    graph_z = np.clip((graph_dist-graph_dist.mean())/(graph_dist.std()+1e-8), -10,10)
    if len(lstm_z) != len(seq_labels): continue
    lstm_only_scores.append(lstm_z); gnn_only_scores.append(graph_z)
    combined_scores.append((lstm_z+graph_z)/2); labels_all.append(seq_labels)
    tune_all.append(offset+tune_idx); final_all.append(offset+final_idx)
    offset += len(seq_labels)

lstm_only_scores = np.concatenate(lstm_only_scores)
gnn_only_scores = np.concatenate(gnn_only_scores)
combined_scores = np.concatenate(combined_scores)
labels_all = np.concatenate(labels_all)
tune_all = np.concatenate(tune_all); final_all = np.concatenate(final_all)

print("\n---- Ablation (based on final run's models) ----")
print("LSTM only F1:    ", round(eval_score(lstm_only_scores, labels_all, tune_all, final_all), 3))
print("GNN only F1:     ", round(eval_score(gnn_only_scores, labels_all, tune_all, final_all), 3))
print("LSTM+GNN avg F1: ", round(eval_score(combined_scores, labels_all, tune_all, final_all), 3))

# ---- inspect learned attention: which channels matter to each other ----
import pandas as pd
attn_df = pd.DataFrame(final_attn.cpu().numpy(), index=chan_list, columns=chan_list)
print("\nTop attention weight per channel:")
for chan in chan_list:
    row = attn_df.loc[chan].drop(chan, errors="ignore")
    if len(row) > 0:
        print(f"  {chan} attends most to {row.idxmax()} (weight={row.max():.3f})")
# Out:
# Mean F1 across 5 runs: 0.365 ± 0.006
# Min: 0.355  Max: 0.372
#
# Skipped channels:
#   A-5: train=31, test=230 -> too few train windows
#   A-6: train=30, test=218 -> too few train windows
#   A-8: train=34, test=414 -> too few train windows
#   A-9: train=34, test=417 -> too few train windows
#   C-2: train=34, test=98 -> too few train windows
#   D-12: train=11, test=391 -> too few train windows
#   T-8: train=33, test=71 -> too few train windows
#   T-9: train=17, test=50 -> too few train windows
#
# ---- Ablation (based on final run's models) ----
# LSTM only F1:     0.431
# GNN only F1:      0.239
# LSTM+GNN avg F1:  0.43
#
# Top attention weight per channel:
#   A-1 attends most to A-4 (weight=0.493)
#   A-2 attends most to A-4 (weight=0.709)
#   A-3 attends most to A-4 (weight=0.500)
#   A-4 attends most to A-2 (weight=0.641)
#   A-7 attends most to A-4 (weight=0.500)
#   B-1 attends most to A-1 (weight=0.014)
#   C-1 attends most to A-1 (weight=0.014)
#   D-1 attends most to D-16 (weight=0.985)
#   D-11 attends most to D-16 (weight=0.986)
#   D-13 attends most to D-16 (weight=0.986)
#   D-14 attends most to D-16 (weight=0.986)
#   D-15 attends most to D-16 (weight=0.986)
#   D-16 attends most to D-3 (weight=0.093)
#   D-2 attends most to D-16 (weight=0.986)
#   D-3 attends most to D-16 (weight=0.986)
#   D-4 attends most to D-16 (weight=0.986)
#   D-5 attends most to D-16 (weight=0.986)
#   D-6 attends most to D-16 (weight=0.986)
#   D-7 attends most to D-16 (weight=0.986)
#   D-8 attends most to D-16 (weight=0.986)
#   D-9 attends most to D-16 (weight=0.986)
#   E-1 attends most to E-13 (weight=0.111)
#   E-10 attends most to E-13 (weight=0.114)
#   E-11 attends most to E-13 (weight=0.112)
#   E-12 attends most to E-13 (weight=0.112)
#   E-13 attends most to E-3 (weight=0.107)
#   E-2 attends most to E-13 (weight=0.112)
#   E-3 attends most to E-13 (weight=0.115)
#   E-4 attends most to E-13 (weight=0.111)
#   E-5 attends most to E-13 (weight=0.114)
#   E-6 attends most to E-13 (weight=0.113)
#   E-7 attends most to E-13 (weight=0.113)
#   E-8 attends most to E-13 (weight=0.112)
#   E-9 attends most to E-13 (weight=0.111)
#   F-1 attends most to F-5 (weight=0.810)
#   F-2 attends most to F-5 (weight=0.794)
#   F-3 attends most to F-5 (weight=0.810)
#   F-4 attends most to F-5 (weight=0.802)
#   F-5 attends most to F-8 (weight=0.201)
#   F-7 attends most to F-5 (weight=0.803)
#   F-8 attends most to F-5 (weight=0.812)
#   G-1 attends most to G-3 (weight=0.870)
#   G-2 attends most to G-3 (weight=0.874)
#   G-3 attends most to G-6 (weight=0.370)
#   G-4 attends most to G-3 (weight=0.852)
#   G-6 attends most to G-3 (weight=0.897)
#   G-7 attends most to G-3 (weight=0.872)
#   M-1 attends most to M-7 (weight=0.894)
#   M-2 attends most to M-7 (weight=0.869)
#   M-3 attends most to M-7 (weight=0.885)
#   M-4 attends most to M-7 (weight=0.868)
#   M-5 attends most to M-7 (weight=0.870)
#   M-6 attends most to M-7 (weight=0.870)
#   M-7 attends most to M-1 (weight=0.303)
#   P-1 attends most to P-2 (weight=0.175)
#   P-10 attends most to P-2 (weight=0.179)
#   P-11 attends most to P-2 (weight=0.190)
#   P-14 attends most to P-2 (weight=0.183)
#   P-15 attends most to P-2 (weight=0.175)
#   P-2 attends most to P-11 (weight=0.181)
#   P-3 attends most to P-2 (weight=0.178)
#   P-4 attends most to P-2 (weight=0.180)
#   P-7 attends most to P-2 (weight=0.179)
#   R-1 attends most to A-1 (weight=0.014)
#   S-1 attends most to S-2 (weight=1.000)
#   S-2 attends most to S-1 (weight=1.000)
#   T-1 attends most to T-2 (weight=0.309)
#   T-12 attends most to T-2 (weight=0.292)
#   T-13 attends most to T-2 (weight=0.302)
#   T-2 attends most to T-1 (weight=0.202)
#   T-3 attends most to T-2 (weight=0.307)
#   T-4 attends most to T-2 (weight=0.295)
#   T-5 attends most to T-2 (weight=0.294)
